# %% [markdown]
# # Part 1: Data Preprocessing

# %% [markdown]
# Dataset Link: https://www.kaggle.com/datasets/arjunbhasin2013/ccdata

# %% [markdown]
# ## Importing the libraries and dataset

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv('/content/CC GENERAL.csv')

# %%
dataset.head()
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 4  C10005   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# ...

# %% [markdown]
# ## Data Exploration

# %%
dataset.shape
# Out:
# (8950, 18)

# %%
dataset.columns
# Out:
# Index(['CUST_ID', 'BALANCE', 'BALANCE_FREQUENCY', 'PURCHASES',
#        'ONEOFF_PURCHASES', 'INSTALLMENTS_PURCHASES', 'CASH_ADVANCE',
#        'PURCHASES_FREQUENCY', 'ONEOFF_PURCHASES_FREQUENCY',
#        'PURCHASES_INSTALLMENTS_FREQUENCY', 'CASH_ADVANCE_FREQUENCY',
#        'CASH_ADVANCE_TRX', 'PURCHASES_TRX', 'CREDIT_LIMIT', 'PAYMENTS',
#        'MINIMUM_PAYMENTS', 'PRC_FULL_PAYMENT', 'TENURE'],
#       dtype='object')

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8950 entries, 0 to 8949
# Data columns (total 18 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   CUST_ID                           8950 non-null   object
#  1   BALANCE                           8950 non-null   float64
#  2   BALANCE_FREQUENCY                 8950 non-null   float64
#  3   PURCHASES                         8950 non-null   float64
#  4   ONEOFF_PURCHASES                  8950 non-null   float64
#  5   INSTALLMENTS_PURCHASES            8950 non-null   float64
#  6   CASH_ADVANCE                      8950 non-null   float64
#  7   PURCHASES_FREQUENCY               8950 non-null   float64
#  8   ONEOFF_PURCHASES_FREQUENCY        8950 non-null   float64
#  9   PURCHASES_INSTALLMENTS_FREQUENCY  8950 non-null   float64
#  10  CASH_ADVANCE_FREQUENCY            8950 non-null   float64
# ...

# %%
# Categorical columns
print(f"Columns with categorical values are : {dataset.select_dtypes(include = 'object').columns}")
print(f"Number of columns with categorical values : {len(dataset.select_dtypes(include = 'object').columns)}")
# Out:
# Columns with categorical values are : Index(['CUST_ID'], dtype='object')
# Number of columns with categorical values : 1

# %%
# Numerical columns
print(f"Columns with numerical values are {dataset.select_dtypes(include = ['int64', 'float64']).columns} ")
print(f"Number of columns with numerical values : {len(dataset.select_dtypes(include = ['int64', 'float64']).columns)}")
# Out:
# Columns with numerical values are Index(['BALANCE', 'BALANCE_FREQUENCY', 'PURCHASES', 'ONEOFF_PURCHASES',
#        'INSTALLMENTS_PURCHASES', 'CASH_ADVANCE', 'PURCHASES_FREQUENCY',
#        'ONEOFF_PURCHASES_FREQUENCY', 'PURCHASES_INSTALLMENTS_FREQUENCY',
#        'CASH_ADVANCE_FREQUENCY', 'CASH_ADVANCE_TRX', 'PURCHASES_TRX',
#        'CREDIT_LIMIT', 'PAYMENTS', 'MINIMUM_PAYMENTS', 'PRC_FULL_PAYMENT',
#        'TENURE'],
#       dtype='object')
# Number of columns with numerical values : 17

# %%
# statistical summary
dataset.describe()
# Out:
#             BALANCE  BALANCE_FREQUENCY     PURCHASES  ONEOFF_PURCHASES  \
# count   8950.000000        8950.000000   8950.000000       8950.000000
# mean    1564.474828           0.877271   1003.204834        592.437371
# std     2081.531879           0.236904   2136.634782       1659.887917
# min        0.000000           0.000000      0.000000          0.000000
# 25%      128.281915           0.888889     39.635000          0.000000
# 50%      873.385231           1.000000    361.280000         38.000000
# 75%     2054.140036           1.000000   1110.130000        577.405000
# max    19043.138560           1.000000  49039.570000      40761.250000
#
#        INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# count             8950.000000   8950.000000          8950.000000
# mean               411.067645    978.871112             0.490351
# std                904.338115   2097.163877             0.401371
# min                  0.000000      0.000000             0.000000
# ...

# %% [markdown]
# The dataset relates to credit card usage with an average balance of $1564.47 and an average purchase amount of $1003.20. Customers make various types of purchases, with an average one-off purchase of $592.44 and installment purchases of $411.07. Cash advances have an average amount of $978.87. On average, customers make purchases 14.71 times, with a credit limit averaging $4494.45.
#
# Some customers exhibit full payment behavior, as reflected by the mean of 0.15 in the PRC_FULL_PAYMENT column. The dataset suggests diverse credit behaviors, with a wide range of balances, purchase amounts, and credit limits. Further analysis could reveal patterns and insights into customer credit usage.

# %% [markdown]
# ## Dealing with missing values

# %%
print(f"Is there any null values : {dataset.isnull().values.any()}")
print(f"Number of null values : {dataset.isnull().values.sum()}")
# Out:
# Is there any null values : True
# Number of null values : 314

# %%
print(f"Columns with null values are : {dataset.columns[dataset.isnull().any()]}")
print(f"Number of columns with null values : {len(dataset.columns[dataset.isnull().any()])}")
# Out:
# Columns with null values are : Index(['CREDIT_LIMIT', 'MINIMUM_PAYMENTS'], dtype='object')
# Number of columns with null values : 2

# %%
for col in dataset.columns[dataset.isnull().any()]:
  dataset[col]  =dataset[col].fillna(dataset[col].mean())

# %%
print(f"Columns with null values are : {dataset.columns[dataset.isnull().any()]}")
print(f"Number of columns with null values : {len(dataset.columns[dataset.isnull().any()])}")
# Out:
# Columns with null values are : Index([], dtype='object')
# Number of columns with null values : 0

# %% [markdown]
# ## Encoding Categorical data

# %%
# Categorical columns
print(f"Columns with categorical values are : {dataset.select_dtypes(include = 'object').columns}")
print(f"Number of columns with categorical values : {len(dataset.select_dtypes(include = 'object').columns)}")
# Out:
# Columns with categorical values are : Index(['CUST_ID'], dtype='object')
# Number of columns with categorical values : 1

# %%
# cust_id columns not have any impact on our model so can be dropped
dataset = dataset.drop(columns = 'CUST_ID')

# %%
# Categorical columns
print(f"Columns with categorical values are : {dataset.select_dtypes(include = 'object').columns}")
print(f"Number of columns with categorical values : {len(dataset.select_dtypes(include = 'object').columns)}")
# Out:
# Columns with categorical values are : Index([], dtype='object')
# Number of columns with categorical values : 0

# %% [markdown]
# ## Correlation matrix

# %%
corr = dataset.corr()

# %%
# heatmap
plt.figure(figsize = (16,9))
ax = sns.heatmap(corr, annot = True, cmap = 'coolwarm')

# %% [markdown]
# ## Splitting the dataset

# %%
# only independent variable not target variable

# %% [markdown]
# ## Feature Scaling

# %%
df = dataset

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler()
dataset = sc.fit_transform(dataset)

# %%
dataset
# Out:
# array([[-0.73198937, -0.24943448, -0.42489974, ..., -0.31096755,
#         -0.52555097,  0.36067954],
#        [ 0.78696085,  0.13432467, -0.46955188, ...,  0.08931021,
#          0.2342269 ,  0.36067954],
#        [ 0.44713513,  0.51808382, -0.10766823, ..., -0.10166318,
#         -0.52555097,  0.36067954],
#        ...,
#        [-0.7403981 , -0.18547673, -0.40196519, ..., -0.33546549,
#          0.32919999, -4.12276757],
#        [-0.74517423, -0.18547673, -0.46955188, ..., -0.34690648,
#          0.32919999, -4.12276757],
#        [-0.57257511, -0.88903307,  0.04214581, ..., -0.33294642,
#         -0.52555097, -4.12276757]])

# %% [markdown]
# # Part 2: Elbow method ( finding the optimal number of clusters )

# %%
from sklearn.cluster import KMeans

# %%
wcss = [] # within square sum of square
for i in range(1, 20):
  kmeans = KMeans(n_clusters = i, init = "k-means++")
  kmeans.fit(dataset)
  wcss.append(kmeans.inertia_)
plt.plot(range(1, 20), wcss, 'bx-')
plt.title('The elbo method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %% [markdown]
# By seeing graph the optimal value of cluster is 8

# %% [markdown]
# # Part 3: Building the model

# %%
kmeans = KMeans(n_clusters=8 , init = 'k-means++', random_state = 0)

# %%
# dependent variable
y_kmeans = kmeans.fit_predict(dataset)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
y_kmeans
# Out:
# array([0, 3, 5, ..., 7, 7, 7], dtype=int32)

# %%
# unique values ie 8 clusters
set(y_kmeans)
# Out:
# {0, 1, 2, 3, 4, 5, 6, 7}

# %% [markdown]
# # Part 4: Getting the output

# %%
y_kmeans.shape
# Out:
# (8950,)

# %%
y_kmeans = y_kmeans.reshape(len(y_kmeans), 1)

# %%
y_kmeans.shape
# Out:
# (8950, 1)

# %%
b = np.concatenate((y_kmeans, df), axis = 1)

# %%
df.columns
# Out:
# Index(['BALANCE', 'BALANCE_FREQUENCY', 'PURCHASES', 'ONEOFF_PURCHASES',
#        'INSTALLMENTS_PURCHASES', 'CASH_ADVANCE', 'PURCHASES_FREQUENCY',
#        'ONEOFF_PURCHASES_FREQUENCY', 'PURCHASES_INSTALLMENTS_FREQUENCY',
#        'CASH_ADVANCE_FREQUENCY', 'CASH_ADVANCE_TRX', 'PURCHASES_TRX',
#        'CREDIT_LIMIT', 'PAYMENTS', 'MINIMUM_PAYMENTS', 'PRC_FULL_PAYMENT',
#        'TENURE'],
#       dtype='object')

# %%
df_final = pd.DataFrame(data = b, columns = ['Cluster_Number', 'BALANCE', 'BALANCE_FREQUENCY', 'PURCHASES', 'ONEOFF_PURCHASES',
       'INSTALLMENTS_PURCHASES', 'CASH_ADVANCE', 'PURCHASES_FREQUENCY',
       'ONEOFF_PURCHASES_FREQUENCY', 'PURCHASES_INSTALLMENTS_FREQUENCY',
       'CASH_ADVANCE_FREQUENCY', 'CASH_ADVANCE_TRX', 'PURCHASES_TRX',
       'CREDIT_LIMIT', 'PAYMENTS', 'MINIMUM_PAYMENTS', 'PRC_FULL_PAYMENT',
       'TENURE'])

# %%
df_final.head()
# Out:
#    Cluster_Number      BALANCE  BALANCE_FREQUENCY  PURCHASES  \
# 0             0.0    40.900749           0.818182      95.40
# 1             3.0  3202.467416           0.909091       0.00
# 2             5.0  2495.148862           1.000000     773.17
# 3             0.0  1666.670542           0.636364    1499.00
# 4             0.0   817.714335           1.000000      16.00
#
#    ONEOFF_PURCHASES  INSTALLMENTS_PURCHASES  CASH_ADVANCE  \
# 0              0.00                    95.4      0.000000
# 1              0.00                     0.0   6442.945483
# 2            773.17                     0.0      0.000000
# 3           1499.00                     0.0    205.788017
# 4             16.00                     0.0      0.000000
#
#    PURCHASES_FREQUENCY  ONEOFF_PURCHASES_FREQUENCY  \
# 0             0.166667                    0.000000
# 1             0.000000                    0.000000
# 2             1.000000                    1.000000
# ...

# %%
df_final.to_csv('Segmented_customers')
